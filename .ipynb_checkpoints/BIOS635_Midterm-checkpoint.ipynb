# %%
# Load libraries
import pandas as pd
import pandas.api.types
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import optuna
import time
from lifelines import KaplanMeierFitter, CoxPHFitter
from lifelines.utils import concordance_index
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import Lasso, LassoCV, Ridge, RidgeCV
from sklearn.model_selection import KFold, train_test_split, GridSearchCV, cross_val_score, RepeatedKFold
from xgboost import XGBRegressor

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# C:\Users\ashle\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Load data
data = pd.read_csv("C:/Users/ashle/OneDrive/Documents/Courses/UNC Courses/BIOS 635 - ML/Midterm/train.csv")
data_test = pd.read_csv("C:/Users/ashle/OneDrive/Documents/Courses/UNC Courses/BIOS 635 - ML/Midterm/test.csv")

# %% [markdown]
# # Data Preprocessing

# %%
# Examine data
print(data.shape)
print(data_test.shape)
data.head()
# Out:
# (28800, 60)
# (3, 58)
#    ID                       dri_score psych_disturb    cyto_score diabetes  \
# 0   0  N/A - non-malignant indication            No           NaN       No
# 1   1                    Intermediate            No  Intermediate       No
# 2   2  N/A - non-malignant indication            No           NaN       No
# 3   3                            High            No  Intermediate       No
# 4   4                            High            No           NaN       No
#
#    hla_match_c_high  hla_high_res_8          tbi_status arrhythmia  \
# 0               NaN             NaN              No TBI         No
# 1               2.0             8.0  TBI +- Other, >cGy         No
# 2               2.0             8.0              No TBI         No
# 3               2.0             8.0              No TBI         No
# 4               2.0             8.0              No TBI         No
#
#    hla_low_res_6  ...          tce_div_match donor_related  \
# 0            6.0  ...                    NaN     Unrelated
# 1            6.0  ...  Permissive mismatched       Related
# 2            6.0  ...  Permissive mismatched       Related
# 3            6.0  ...  Permissive mismatched     Unrelated
# 4            6.0  ...  Permissive mismatched       Related
#
#        melphalan_dose hla_low_res_8 cardiac  hla_match_drb1_high  \
# 0  N/A, Mel not given           8.0      No                  2.0
# 1  N/A, Mel not given           8.0      No                  2.0
# 2  N/A, Mel not given           8.0      No                  2.0
# 3  N/A, Mel not given           8.0      No                  2.0
# 4                 MEL           8.0      No                  2.0
#
#   pulm_moderate  hla_low_res_10  efs efs_time
# 0            No            10.0  0.0   42.356
# 1           Yes            10.0  1.0    4.672
# 2            No            10.0  0.0   19.793
# 3            No            10.0  0.0  102.349
# 4            No            10.0  0.0   16.223
#
# [5 rows x 60 columns]

# %%
# Replace missing data

# Check missing values
print(f"Number of rows with NaN in Train: {data.isnull().any(axis=1).sum()}")

# Fill numerical variables with median
for col in data.select_dtypes(include=['number']).columns:  
    data[col].fillna(data[col].median(), inplace=True)

# Fill categorical variables with mode
for col in data.select_dtypes(include=['object']).columns:  
    data[col].fillna(data[col].mode()[0], inplace=True)
    
# Check NaNs are removed
print(f"Number of rows with NaN in Train now: {data.isnull().any(axis=1).sum()}")

# Do the same preprocessing for test set
print(f"Number of rows with NaN in Test: {data_test.isnull().any(axis=1).sum()}")

for col in data_test.select_dtypes(include=['number']).columns:  
    data_test[col].fillna(data_test[col].median(), inplace=True)

for col in data_test.select_dtypes(include=['object']).columns:  
    data_test[col].fillna(data_test[col].mode()[0], inplace=True)
    
print(f"Number of rows with NaN in Test now: {data_test.isnull().any(axis=1).sum()}")
# Out:
# Number of rows with NaN in Train: 26826
# Number of rows with NaN in Train now: 0
# Number of rows with NaN in Test: 2
# Number of rows with NaN in Test now: 0

# %%
# Define a function to calculate the survival rate
def transform_survival_rate(df, time='efs_time', event='efs'):
    """
    Transform the efs and efs_time data into survival rates using the Kaplan-Meier estimator.
    """
    kmf = KaplanMeierFitter()  # initalize estimator
    kmf.fit(df[time], df[event])  # fit the estimator
    survival_prob = kmf.survival_function_at_times(df[time]).to_numpy().flatten()  # calculate probabilites
    df["survival_rate"] = survival_prob  # add probabilities as new variable   
    return df

# Adding survival rate and risk score, the response variable
data = transform_survival_rate(data, "efs_time", "efs")
data['risk_score'] = np.log(data['survival_rate'] / (1 - data['survival_rate']))

data.head()
# Out:
#    ID                       dri_score psych_disturb    cyto_score diabetes  \
# 0   0  N/A - non-malignant indication            No          Poor       No
# 1   1                    Intermediate            No  Intermediate       No
# 2   2  N/A - non-malignant indication            No          Poor       No
# 3   3                            High            No  Intermediate       No
# 4   4                            High            No          Poor       No
#
#    hla_match_c_high  hla_high_res_8          tbi_status arrhythmia  \
# 0               2.0             8.0              No TBI         No
# 1               2.0             8.0  TBI +- Other, >cGy         No
# 2               2.0             8.0              No TBI         No
# 3               2.0             8.0              No TBI         No
# 4               2.0             8.0              No TBI         No
#
#    hla_low_res_6  ...      melphalan_dose hla_low_res_8 cardiac  \
# 0            6.0  ...  N/A, Mel not given           8.0      No
# 1            6.0  ...  N/A, Mel not given           8.0      No
# 2            6.0  ...  N/A, Mel not given           8.0      No
# 3            6.0  ...  N/A, Mel not given           8.0      No
# 4            6.0  ...                 MEL           8.0      No
#
#   hla_match_drb1_high pulm_moderate  hla_low_res_10  efs  efs_time  \
# 0                 2.0            No            10.0  0.0    42.356
# 1                 2.0           Yes            10.0  1.0     4.672
# 2                 2.0            No            10.0  0.0    19.793
# 3                 2.0            No            10.0  0.0   102.349
# 4                 2.0            No            10.0  0.0    16.223
#
#    survival_rate risk_score
# 0       0.458687  -0.165630
# 1       0.847759   1.717134
# 2       0.462424  -0.150587
# 3       0.456661  -0.173792
# 4       0.464674  -0.141542
#
# [5 rows x 62 columns]

# %%
# Remove ID - unnecessary variable
data.drop(columns=['ID'], inplace=True)

# Identify numerical features
num_cols = data.select_dtypes(include=['number']).columns
num_cols = [col for col in num_cols if col not in ['efs', 'efs_time']]

# Standardize numerical features
stadardize = StandardScaler()
data[num_cols] = stadardize.fit_transform(data[num_cols])

# Identify categorical features
cat_cols = data.select_dtypes(include=['object']).columns.tolist()
print("Number of categorical features:", len(cat_cols))

# label encoding for ordinal features
ordinal_features = ["dri_score", "cyto_score", "cyto_score_detail"]
for i in ordinal_features:
    encoder = LabelEncoder()
    data[i] = encoder.fit_transform(data[i])
print("Number of columns after label encoding", len(data.columns))

# One-hot encoding for nominal features
nominal_features = [col for col in cat_cols if col not in ordinal_features]
fixed_data = pd.get_dummies(data, columns=nominal_features, drop_first=True)
print("Number of columns after one-hot encoding", len(fixed_data.columns))

# Repeat for test set
for i in ordinal_features:
    encoder = LabelEncoder()
    data_test[i] = encoder.fit_transform(data_test[i])
print("Number of columns after label encoding test data", len(data_test.columns))

fixed_data_test = pd.get_dummies(data_test, columns=nominal_features, drop_first=True)
print("Number of columns after one-hot encoding test data", len(fixed_data_test.columns))
# Out:
# Number of categorical features: 35
# Number of columns after label encoding 61
# Number of columns after one-hot encoding 135
# Number of columns after label encoding test data 58
# Number of columns after one-hot encoding test data 39

# %%
# Kaggle given function for stratified C-index to evaluate model performance
def score(solution: pd.DataFrame, submission: pd.DataFrame, row_id_column_name: str) -> float:
    
    del solution[row_id_column_name]
    del submission[row_id_column_name]
    
    event_label = 'efs'
    interval_label = 'efs_time'
    prediction_label = 'prediction'
    for col in submission.columns:
         if not pandas.api.types.is_numeric_dtype(submission[col]):
            raise ParticipantVisibleError(f'Submission column {col} must be a number')
    # Merging solution and submission dfs on ID
    merged_df = pd.concat([solution, submission], axis=1)
    merged_df.reset_index(inplace=True)
    merged_df_race_dict = dict(merged_df.groupby(['race_group']).groups)
    metric_list = []
    for race in merged_df_race_dict.keys():
        # Retrieving values from y_test based on index
        indices = sorted(merged_df_race_dict[race])
        merged_df_race = merged_df.iloc[indices]
        # Calculate the concordance index
        c_index_race = concordance_index(
                        merged_df_race[interval_label],
                        -merged_df_race[prediction_label],
                        merged_df_race[event_label])
        metric_list.append(c_index_race)
    return float(np.mean(metric_list)-np.sqrt(np.var(metric_list)))

# Function to prepare model results into a form accepted by score()
def strat_c_index(y_pred, data):
    """ 
    The score() function takes in the dataframes solution and submission and returns the C-index stratified on race. 
    """
    id_col_name = 'ID'
    
    # submission dataframe
    y_pred = {'prediction': y_pred}
    y_pred = pd.DataFrame(y_pred)
    y_pred.insert(0, id_col_name, range(len(y_pred)))
    
    # solution dataframe
    y_true = data[['efs', 'efs_time', 'race_group']].copy()
    y_true = pd.DataFrame(y_true)
    y_true.insert(0, id_col_name, range(len(y_true)))
    
    # drop index in case of misalignment from merging data in score()
    y_true = y_true.reset_index(drop=True)
    y_pred = y_pred.reset_index(drop=True)
    
    # call score() to get stratified C-index
    index = score(y_true, y_pred, id_col_name)
    
    return index

# %%
# Identify features (X) and response (y) variables 
X = fixed_data.drop(columns=['efs_time', 'efs', 'survival_rate', 'risk_score'])
y = fixed_data['risk_score']

# %% [markdown]
# # Method 1: Ridge Regression

# %%
# Create a function for Ridge Regression
def ridge(X, y, k, data):
    """"
    This function finds the best ridge regression model based on K-fold cross validation.
    
    X: features data
    y: response variable
    k: number of folds for cross validation
    data: original cleaned data for stratified C-index calculations
    """
    # Start timer
    start_time = time.time()  
    
    # Train-validation split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)
    
    # Grid search tuning to find best lambda using cross-validation
    grid = 10 ** np.linspace(-4, 4, num=100)  
    
    print("Training Ridge model with", k, "cross-validation...")
    
    ridge = RidgeCV(alphas=grid, cv=5)
    ridge.fit(X_train, y_train)
    best_lambda = ridge.alpha_
    print(f"Best lambda: {best_lambda}")
    
    # Get best Ridge model
    best_ridge = Ridge(alpha=best_lambda)
    best_ridge.fit(X_train, y_train)
    
    # Make predictions
    y_predicts = best_ridge.predict(X_test)

    # Calculate MSE of predictions
    mse = mean_squared_error(y_test, y_predicts)
    print(f"MSE: {mse}")
    
    # Calculate stratified C-index
    data_train, data_test = train_test_split(data, test_size=0.3, random_state=7)
    c = strat_c_index(y_predicts, data_test)
    
    # End timer
    end_time = time.time()  
    elapsed_time = end_time - start_time 
    print(f"Time taken: {elapsed_time:.2f} seconds") 
    
    return best_ridge, y_predicts, mse, c, elapsed_time

# %%
# Test different K-folds CV
ridge_3, y_ridge_3, mse_ridge_3, c_ridge_3, time_ridge_3 = ridge(X, y, 3, data)
ridge_5, y_ridge_5, mse_ridge_5, c_ridge_5, time_ridge_5 = ridge(X, y, 5, data)
ridge_8, y_ridge_8, mse_ridge_8, c_ridge_8, time_ridge_8 = ridge(X, y, 8, data)
ridge_10, y_ridge_10, mse_ridge_10, c_ridge_10, time_ridge_10 = ridge(X, y, 10, data)
# Out:
# Training Ridge model with 3 cross-validation...
# Best lambda: 54.62277217684348
# MSE: 0.8789758715751355
# Time taken: 37.12 seconds
# Training Ridge model with 5 cross-validation...
# Best lambda: 54.62277217684348
# MSE: 0.8789758715751355
# Time taken: 33.74 seconds
# Training Ridge model with 8 cross-validation...
# Best lambda: 54.62277217684348
# MSE: 0.8789758715751355
# Time taken: 34.83 seconds
# Training Ridge model with 10 cross-validation...
# Best lambda: 54.62277217684348
# MSE: 0.8789758715751355
# Time taken: 34.49 seconds

# %%
# Combine data from Ridge 
k_folds = [3, 5, 8, 10]
mse_values = [mse_ridge_3, mse_ridge_5, mse_ridge_8, mse_ridge_10]
time_taken = [time_ridge_3, time_ridge_5, time_ridge_8, time_ridge_10]
c_val = [c_ridge_3, c_ridge_5, c_ridge_8, c_ridge_10]

fig, ax1 = plt.subplots()

# Plot MSE on the left y-axis
ax1.set_xlabel("Number of K-Folds")
ax1.set_ylabel("MSE", color="tab:blue")
ax1.plot(k_folds, mse_values, marker="o", color="tab:blue", label="MSE")
ax1.tick_params(axis="y", labelcolor="tab:blue")

# Create a second y-axis for stratified C-index
ax2 = ax1.twinx()
ax2.set_ylabel("Stratified C-Index Score", color="tab:red")
ax2.plot(k_folds, c_val, marker="s", linestyle="dashed", color="tab:red", label="C-index")
ax2.tick_params(axis="y", labelcolor="tab:red")

# Create a third axis for time
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))  # Shift the third axis outward
ax3.set_ylabel("Time (seconds)", color="tab:green")
ax3.plot(k_folds, time_taken, marker="^", color="tab:green", label="Time Taken")
ax3.tick_params(axis="y", labelcolor="tab:green")

# Title and layout adjustments
plt.title("Ridge Regression: MSE, C-index, & Time vs. K-Fold CV")
fig.tight_layout()
plt.show()

# %%
# Plot lambda vs MSE for training and test sets
mse_train_ridge = []
mse_test_ridge = []

# Loop through the grid of alphas to compute MSE for each value of alpha
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)
grid = 10 ** np.linspace(-4, 4, num=100)  
for alpha in grid:
    ridge = RidgeCV(alphas=[alpha], cv=5)
    ridge.fit(X_train, y_train)
    y_train_pred_ridge = ridge.predict(X_train)
    y_test_pred_ridge = ridge.predict(X_test)
    
    mse_train_ridge.append(mean_squared_error(y_train, y_train_pred_ridge))
    mse_test_ridge.append(mean_squared_error(y_test, y_test_pred_ridge))

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (20160, 131)
# (8640, 131)

# %%
# Plot MSE vs lambda for Ridge
plt.figure(figsize=(10, 6))
plt.plot(grid, mse_train_ridge, label="Train MSE", color='blue')
plt.plot(grid, mse_test_ridge, label="Test MSE", color='red')
plt.xscale('log')
plt.xlabel('Lambda')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Lambda vs MSE for Train and Test Set with Ridge Regression')
plt.legend()
plt.show()

# %% [markdown]
# # Method 2: Lasso

# %%
# Create a function for Lasso 
def lasso(X, y, k, data):
    """"
    This function finds the best lasso model based on K-fold cross validation.
    
    X: features data
    y: response variable
    k: number of folds for cross validation
    data: original cleaned data for stratified C-index calculations
    """
    # Start timer
    start_time = time.time()  
    
    # Train-validation split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)

    # Grid search tuning to find best lambda using cross validation
    grid = 10 ** np.linspace(-4, 4, num=100)
    
    print("Training Lasso model with", k, "cross-validation...")
    
    lasso = LassoCV(alphas=grid, cv=k)
    lasso.fit(X_train, y_train)
    best_lambda = lasso.alpha_
    print(f"Best lambda: {best_lambda}")
    
    # Get best Lasso model
    best_lasso = Lasso(alpha=best_lambda)
    best_lasso.fit(X_train, y_train)
    
    # Make predictions
    y_predicts = best_lasso.predict(X_test)

    # Calculate MSE of predictions
    mse = mean_squared_error(y_test, y_predicts)
    print(f"MSE: {mse}")
    
    # Calculate stratified C-index
    data_train, data_test = train_test_split(data, test_size=0.3, random_state=7)
    c = strat_c_index(y_predicts, data_test)
    
    # End timer
    end_time = time.time()  
    elapsed_time = end_time - start_time 
    print(f"Time taken: {elapsed_time:.2f} seconds") 
    
    return best_lasso, y_predicts, mse, c, elapsed_time

# %%
# Test different K-fold CV 
lasso_3, y_lasso_3, mse_lasso_3, c_lasso_3, time_lasso_3 = lasso(X, y, 3, data)
lasso_5, y_lasso_5, mse_lasso_5, c_lasso_5, time_lasso_5 = lasso(X, y, 5, data)
lasso_8, y_lasso_8, mse_lasso_8, c_lasso_8, time_lasso_8 = lasso(X, y, 8, data)
lasso_10, y_lasso_10, mse_lasso_10, c_lasso_10, time_lasso_10 = lasso(X, y, 10, data)
# Out:
# Training Lasso model with 3 cross-validation...
# Best lambda: 0.0006428073117284319
# MSE: 0.8794310019882009
# Time taken: 3.09 seconds
# Training Lasso model with 5 cross-validation...
# Best lambda: 0.0006428073117284319
# MSE: 0.8794310019882009
# Time taken: 2.76 seconds
# Training Lasso model with 8 cross-validation...
# Best lambda: 0.0005336699231206312
# MSE: 0.8790648954198851
# Time taken: 3.42 seconds
# Training Lasso model with 10 cross-validation...
# Best lambda: 0.0004430621457583882
# MSE: 0.8788349596358462
# Time taken: 3.73 seconds

# %%
# Combine data from Lasso 
k_folds = [3, 5, 8, 10]
mse_values = [mse_lasso_3, mse_lasso_5, mse_lasso_8, mse_lasso_10]
time_taken = [time_lasso_3, time_lasso_5, time_lasso_8, time_lasso_10]
c_values = [c_lasso_3, c_lasso_5, c_lasso_8, c_lasso_10]

fig, ax1 = plt.subplots()

# Plot MSE on the left y-axis
ax1.set_xlabel("Number of K-Folds")
ax1.set_ylabel("MSE", color="tab:blue")
ax1.plot(k_folds, mse_values, marker="o", color="tab:blue", label="MSE")
ax1.tick_params(axis="y", labelcolor="tab:blue")

# Create a second y-axis for Stratified C-index
ax2 = ax1.twinx()
ax2.set_ylabel("Stratified C-Index Score", color="tab:red")
ax2.plot(k_folds, c_values, marker="s", color="tab:red", label="C-index")
ax2.tick_params(axis="y", labelcolor="tab:red")

# Create a third y-axis for time taken
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 70))  # Shift the third axis outward
ax3.set_ylabel("Time (seconds)", color="tab:green")
ax3.plot(k_folds, time_taken, marker="^", color="tab:green", label="Time Taken")
ax3.tick_params(axis="y", labelcolor="tab:green")

# Title and layout adjustments
plt.title("Lasso: MSE, C-index, & Time vs. K-Fold CV")
fig.tight_layout()
plt.show()

# %%
# Plot lambda vs MSE for training and test sets
mse_train_lasso = []
mse_test_lasso = []

# Loop through the grid of alphas to compute MSE for each value of alpha
grid = 10 ** np.linspace(-4, 4, num=100)  
for alpha in grid:
    lasso = LassoCV(alphas=[alpha], cv=10)
    lasso.fit(X_train, y_train)
    y_train_pred_lasso = lasso.predict(X_train)
    y_test_pred_lasso = lasso.predict(X_test)
    
    mse_train_lasso.append(mean_squared_error(y_train, y_train_pred_lasso))
    mse_test_lasso.append(mean_squared_error(y_test, y_test_pred_lasso))

# %%
# Plot MSE vs lambda for Lasso
plt.figure(figsize=(10, 6))
plt.plot(grid, mse_train_lasso, label="Train MSE", color='blue')
plt.plot(grid, mse_test_lasso, label="Test MSE", color='red')
plt.xscale('log')
plt.xlabel('Lambda')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Lambda vs MSE for Train and Test Set with Lasso')
plt.legend()
plt.show()

# %%
# Compare shrinkage results
num_zero_lasso = np.sum(lasso_10.coef_ == 0)
num_nonzero_ridge = np.sum(ridge_5.coef_ != 0)

print(f"Lasso zero coefficients: {num_zero_lasso}")
print(f"Ridge non-zero coefficients: {num_nonzero_ridge}")
# Out:
# Lasso zero coefficients: 29
# Ridge non-zero coefficients: 131

# %%
# Define different lambda
lambdas = np.logspace(-4, 4, 100)

# Fit models
lasso_coefs = [Lasso(alpha=a).fit(X_train, y_train).coef_ for a in lambdas]
ridge_coefs = [Ridge(alpha=a).fit(X_train, y_train).coef_ for a in lambdas]

# Plot coefficient paths
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(lambdas, np.array(lasso_coefs))
plt.xscale('log')
plt.xlabel("Lambda (λ)")
plt.ylabel("Coefficients")
plt.title("Lasso Coefficient Paths")
plt.axhline(0, linestyle="--", color="black")

plt.subplot(1, 2, 2)
plt.plot(lambdas, np.array(ridge_coefs))
plt.xscale('log')
plt.xlabel("Lambda (λ)")
plt.ylabel("Coefficients")
plt.title("Ridge Coefficient Paths")
plt.axhline(0, linestyle="--", color="black")

plt.show()

# %% [markdown]
# # Method 3: XGBoost

# %%
################ Fixing data to be used with XGBoost ################

# Define the set of invalid characters
invalid_chars = {'[', ']', '<'}

# Find feature names containing invalid characters
invalid_features = [name for name in X.columns if any(char in name for char in invalid_chars)]

# Print results
if invalid_features:
    print("Feature names containing invalid characters:", invalid_features)
else:
    print("No invalid feature names found.")

# Create a dictionary to store the new column names
new_column_names = {}

for col in X.columns:
    new_col = col.replace(',', '&').replace('<', 'less than')
    new_column_names[col] = new_col  # Map old names to new names

# Rename columns in the DataFrame
X.rename(columns=new_column_names, inplace=True)
# Out:
# Feature names containing invalid characters: ['tbi_status_TBI +- Other, <=cGy']

# %%
def xgb(X, y, data, n_trials = 10):
    # Start timer
    start_time = time.time()
    
    # Split data into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)
    
    def objective(trial):
        params = {
            'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=200),
            'learning_rate': trial.suggest_loguniform('learning_rate', 0.005, 0.05),
            'max_depth': trial.suggest_int('max_depth', 3, 10),
            'subsample': trial.suggest_uniform('subsample', 0.6, 1.0),
            'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.5, 1.0),
        }
        model = XGBRegressor(**params, objective='reg:squarederror', random_state=7)
        model.fit(X_train, y_train)
        preds = model.predict(X_test)
        return mean_squared_error(y_test, preds, squared=False)  # RMSE

    # Optimize hyperparameters using Optuna
    opt = optuna.create_study(direction='minimize')
    opt.optimize(objective, n_trials=n_trials)

    # Train the final model with best parameters
    best_params = opt.best_params
    best_xgb = XGBRegressor(**best_params, objective='reg:squarederror', random_state=7)
    best_xgb.fit(X_train, y_train)
    
    # Make predictions
    y_pred = best_xgb.predict(X_test)
    
    # Calculate MSE
    mse = mean_squared_error(y_test, y_pred)
    
    # Calculate C-index
    data_train, data_test = train_test_split(data, test_size=0.3, random_state=7)
    c = strat_c_index(y_pred, data_test)
    
    # End timer
    end_time = time.time()
    elapsed_time = end_time - start_time 
    print(f"Time taken: {elapsed_time:.2f} seconds") 

    return best_xgb, y_pred, mse, c, elapsed_time

# %%
xgb_best, xgb_y_pred, xgb_mse, xgb_c, xgb_time = xgb(X, y, data)
# Out:
# [I 2025-03-09 16:22:57,769] A new study created in memory with name: no-name-0ad75265-bcc7-42ca-924b-c405c50eb879
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:00,347] Trial 0 finished with value: 0.8957191185511575 and parameters: {'n_estimators': 700, 'learning_rate': 0.03313531312890926, 'max_depth': 5, 'subsample': 0.6040923257196023, 'colsample_bytree': 0.5548235836373363}. Best is trial 0 with value: 0.8957191185511575.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:02,186] Trial 1 finished with value: 0.9033374270430179 and parameters: {'n_estimators': 500, 'learning_rate': 0.018386253771066566, 'max_depth': 4, 'subsample': 0.982336716099492, 'colsample_bytree': 0.5232134942973548}. Best is trial 0 with value: 0.8957191185511575.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:03,513] Trial 2 finished with value: 0.9038383957958853 and parameters: {'n_estimators': 300, 'learning_rate': 0.019010129033575785, 'max_depth': 5, 'subsample': 0.6465703603596595, 'colsample_bytree': 0.7743232494388436}. Best is trial 0 with value: 0.8957191185511575.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:08,049] Trial 3 finished with value: 0.8990145389311884 and parameters: {'n_estimators': 500, 'learning_rate': 0.01008583724847864, 'max_depth': 10, 'subsample': 0.7134206791135658, 'colsample_bytree': 0.8840423906456214}. Best is trial 0 with value: 0.8957191185511575.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:13,577] Trial 4 finished with value: 0.8964437231647348 and parameters: {'n_estimators': 700, 'learning_rate': 0.016228135258368477, 'max_depth': 10, 'subsample': 0.91249974416371, 'colsample_bytree': 0.5231895124221613}. Best is trial 0 with value: 0.8957191185511575.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:20,361] Trial 5 finished with value: 0.8997378266894285 and parameters: {'n_estimators': 700, 'learning_rate': 0.007297097973377173, 'max_depth': 10, 'subsample': 0.8002619788666792, 'colsample_bytree': 0.9232659472438765}. Best is trial 0 with value: 0.8957191185511575.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:26,170] Trial 6 finished with value: 0.8960520027805376 and parameters: {'n_estimators': 900, 'learning_rate': 0.0132130803674236, 'max_depth': 9, 'subsample': 0.7082915506397378, 'colsample_bytree': 0.5350462606183743}. Best is trial 0 with value: 0.8957191185511575.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:28,687] Trial 7 finished with value: 0.899130531359377 and parameters: {'n_estimators': 500, 'learning_rate': 0.012541479077594186, 'max_depth': 7, 'subsample': 0.6863894001230335, 'colsample_bytree': 0.8990050889770547}. Best is trial 0 with value: 0.8957191185511575.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:30,841] Trial 8 finished with value: 0.8976006683572428 and parameters: {'n_estimators': 700, 'learning_rate': 0.022093082798301304, 'max_depth': 4, 'subsample': 0.7208417153543267, 'colsample_bytree': 0.7680736990244403}. Best is trial 0 with value: 0.8957191185511575.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:34,334] Trial 9 finished with value: 0.9000758589237703 and parameters: {'n_estimators': 500, 'learning_rate': 0.035456583303197564, 'max_depth': 9, 'subsample': 0.6111196877366474, 'colsample_bytree': 0.6474327506542963}. Best is trial 0 with value: 0.8957191185511575.
# Time taken: 39.57 seconds

# %%
xgb_best2, xgb_y_pred2, xgb_mse2, xgb_c2, xgb_time2 = xgb(X, y, data, n_trials=20)
# Out:
# [I 2025-03-09 16:23:37,350] A new study created in memory with name: no-name-2708ba6b-b033-43b5-8e61-7dd168c84dd2
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:40,393] Trial 0 finished with value: 0.899511808948877 and parameters: {'n_estimators': 500, 'learning_rate': 0.023476589723709203, 'max_depth': 7, 'subsample': 0.9413365298371603, 'colsample_bytree': 0.9509437021711573}. Best is trial 0 with value: 0.899511808948877.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:41,092] Trial 1 finished with value: 0.9520257699698554 and parameters: {'n_estimators': 100, 'learning_rate': 0.007385762796991853, 'max_depth': 6, 'subsample': 0.8457791478755119, 'colsample_bytree': 0.5654450211072866}. Best is trial 0 with value: 0.899511808948877.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:42,647] Trial 2 finished with value: 0.8980548886995999 and parameters: {'n_estimators': 300, 'learning_rate': 0.034786316434116074, 'max_depth': 6, 'subsample': 0.6295342647406077, 'colsample_bytree': 0.8094099736983742}. Best is trial 2 with value: 0.8980548886995999.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:44,406] Trial 3 finished with value: 0.9042026210766309 and parameters: {'n_estimators': 300, 'learning_rate': 0.0156370370076822, 'max_depth': 6, 'subsample': 0.7102511047781186, 'colsample_bytree': 0.9217214509019964}. Best is trial 2 with value: 0.8980548886995999.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:47,140] Trial 4 finished with value: 0.9009499547111928 and parameters: {'n_estimators': 500, 'learning_rate': 0.01202452455447418, 'max_depth': 7, 'subsample': 0.9683169746237252, 'colsample_bytree': 0.7729449633393726}. Best is trial 2 with value: 0.8980548886995999.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:48,346] Trial 5 finished with value: 0.9143717102044367 and parameters: {'n_estimators': 300, 'learning_rate': 0.020241950658372778, 'max_depth': 3, 'subsample': 0.7696796437739385, 'colsample_bytree': 0.6913808218127904}. Best is trial 2 with value: 0.8980548886995999.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:49,325] Trial 6 finished with value: 0.9015685800427706 and parameters: {'n_estimators': 100, 'learning_rate': 0.04821639554758664, 'max_depth': 7, 'subsample': 0.7819174176240278, 'colsample_bytree': 0.7191945437357223}. Best is trial 2 with value: 0.8980548886995999.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:52,336] Trial 7 finished with value: 0.894480076792237 and parameters: {'n_estimators': 500, 'learning_rate': 0.03853942174866134, 'max_depth': 6, 'subsample': 0.8714841077564712, 'colsample_bytree': 0.7263004406789859}. Best is trial 7 with value: 0.894480076792237.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:23:57,605] Trial 8 finished with value: 0.8949029703426356 and parameters: {'n_estimators': 700, 'learning_rate': 0.01745795091945935, 'max_depth': 8, 'subsample': 0.687956914645448, 'colsample_bytree': 0.7089240419683468}. Best is trial 7 with value: 0.894480076792237.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:24:00,657] Trial 9 finished with value: 0.9099732499056502 and parameters: {'n_estimators': 500, 'learning_rate': 0.0053934034881942235, 'max_depth': 7, 'subsample': 0.6390150793568095, 'colsample_bytree': 0.8262860930982939}. Best is trial 7 with value: 0.894480076792237.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:24:10,339] Trial 10 finished with value: 0.9039170051841078 and parameters: {'n_estimators': 900, 'learning_rate': 0.033153861682595986, 'max_depth': 10, 'subsample': 0.8764792796367297, 'colsample_bytree': 0.5018680854441111}. Best is trial 7 with value: 0.894480076792237.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:24:18,967] Trial 11 finished with value: 0.8961995494613836 and parameters: {'n_estimators': 900, 'learning_rate': 0.013068285731387862, 'max_depth': 9, 'subsample': 0.7074983503094822, 'colsample_bytree': 0.631911669996075}. Best is trial 7 with value: 0.894480076792237.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:24:22,968] Trial 12 finished with value: 0.8948021439987441 and parameters: {'n_estimators': 700, 'learning_rate': 0.0488166552478416, 'max_depth': 4, 'subsample': 0.8654153975815582, 'colsample_bytree': 0.6469004111561819}. Best is trial 7 with value: 0.894480076792237.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:24:26,872] Trial 13 finished with value: 0.8946739075475635 and parameters: {'n_estimators': 700, 'learning_rate': 0.04948849808434187, 'max_depth': 4, 'subsample': 0.8940692304771465, 'colsample_bytree': 0.6480856622086579}. Best is trial 7 with value: 0.894480076792237.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:24:30,394] Trial 14 finished with value: 0.8947307490796305 and parameters: {'n_estimators': 700, 'learning_rate': 0.031943521128640566, 'max_depth': 4, 'subsample': 0.9156906388536321, 'colsample_bytree': 0.6007424252922502}. Best is trial 7 with value: 0.894480076792237.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:24:33,943] Trial 15 finished with value: 0.8965741984266283 and parameters: {'n_estimators': 700, 'learning_rate': 0.025758366822569514, 'max_depth': 5, 'subsample': 0.9941472361817633, 'colsample_bytree': 0.8989990976747227}. Best is trial 7 with value: 0.894480076792237.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:24:38,397] Trial 16 finished with value: 0.895941073759965 and parameters: {'n_estimators': 900, 'learning_rate': 0.03982858383227928, 'max_depth': 3, 'subsample': 0.8068408221870336, 'colsample_bytree': 0.5431386409912424}. Best is trial 7 with value: 0.894480076792237.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:24:43,174] Trial 17 finished with value: 0.8939625385994453 and parameters: {'n_estimators': 700, 'learning_rate': 0.029067894058247775, 'max_depth': 5, 'subsample': 0.9060256882693384, 'colsample_bytree': 0.6653815072282776}. Best is trial 17 with value: 0.8939625385994453.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:24:46,119] Trial 18 finished with value: 0.8968499262120458 and parameters: {'n_estimators': 500, 'learning_rate': 0.02632899194865017, 'max_depth': 5, 'subsample': 0.8322859603870814, 'colsample_bytree': 0.8382503844396376}. Best is trial 17 with value: 0.8939625385994453.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:24:47,774] Trial 19 finished with value: 0.914548713349135 and parameters: {'n_estimators': 300, 'learning_rate': 0.010668746284180483, 'max_depth': 5, 'subsample': 0.9379495584372358, 'colsample_bytree': 0.7686989485331972}. Best is trial 17 with value: 0.8939625385994453.
# Time taken: 74.30 seconds

# %%
xgb_best3, xgb_y_pred3, xgb_mse3, xgb_c3, xgb_time3 = xgb(X, y, data, n_trials=30)
# Out:
# [I 2025-03-09 16:24:51,666] A new study created in memory with name: no-name-89d3a366-9ea0-4b73-b6d9-e450c804b920
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16

# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:26:50,108] Trial 26 finished with value: 0.8927445326636212 and parameters: {'n_estimators': 900, 'learning_rate': 0.025392211387836646, 'max_depth': 5, 'subsample': 0.7703646182325312, 'colsample_bytree': 0.6183155696622056}. Best is trial 26 with value: 0.8927445326636212.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:26:54,238] Trial 27 finished with value: 0.8927623587183352 and parameters: {'n_estimators': 700, 'learning_rate': 0.021771925755146384, 'max_depth': 6, 'subsample': 0.7791344661572165, 'colsample_bytree': 0.6328180072329848}. Best is trial 26 with value: 0.8927445326636212.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:26:59,083] Trial 28 finished with value: 0.8923428451763025 and parameters: {'n_estimators': 900, 'learning_rate': 0.01986511151005489, 'max_depth': 5, 'subsample': 0.76932915345519, 'colsample_bytree': 0.6369757174285385}. Best is trial 28 with value: 0.8923428451763025.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:27:03,918] Trial 29 finished with value: 0.894183053511469 and parameters: {'n_estimators': 900, 'learning_rate': 0.041644460033083544, 'max_depth': 4, 'subsample': 0.8428366647932626, 'colsample_bytree': 0.740672306629507}. Best is trial 28 with value: 0.8923428451763025.
# Time taken: 137.27 seconds

# %%
xgb_best4, xgb_y_pred4, xgb_mse4, xgb_c4, xgb_time4= xgb(X, y, data, n_trials=40)
# Out:
# [I 2025-03-09 16:27:08,966] A new study created in memory with name: no-name-cc11fa83-6b42-4938-87b5-058181fe7b0e
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:27:10,630] Trial 0 finished with value: 0.9027022741360469 and parameters: {'n_estimators': 300, 'learning_rate': 0.022324918856613692, 'max_depth': 5, 'subsample': 0.7249376485989182, 'colsample_bytree': 0.7194055047615923}. Best is trial 0 with value: 0.9027022741360469.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:27:12,492] Trial 1 finished with value: 0.9151434390162357 and parameters: {'n_estimators': 100, 'learning_rate': 0.018627098159842963, 'max_depth': 10, 'subsample': 0.8120338098602333, 'colsample_bytree': 0.9350488948796476}. Best is trial 0 with value: 0.9027022741360469.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:27:17,428] Trial 2 finished with value: 0.8972581511054794 and parameters: {'n_estimators': 500, 'learning_rate': 0.026537940236893473, 'max_depth': 9, 'subsample': 0.8848483833170813, 'colsample_bytree': 0.5327686538648886}. Best is trial 2 with value: 0.8972581511054794.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:27:21,125] Trial 3 finished with value: 0.8956358919501614 and parameters: {'n_estimators': 500, 'learning_rate': 0.02323190811140152, 'max_depth': 6, 'subsample': 0.7090187619613844, 'colsample_bytree': 0.7711539683041089}. Best is trial 3 with value: 0.8956358919501614.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:27:24,218] Trial 4 finished with value: 0.9188461622086372 and parameters: {'n_estimators': 700, 'learning_rate': 0.006812824178599067, 'max_depth': 3, 'subsample': 0.8149828709266382, 'colsample_bytree': 0.852194704960578}. Best is trial 3 with value: 0.8956358919501614.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:27:35,405] Trial 5 finished with value: 0.8988300392553482 and parameters: {'n_estimators': 900, 'learning_rate': 0.005503115989548093, 'max_depth': 10, 'subsample': 0.7393005283099336, 'colsample_bytree': 0.8475450803956535}. Best is trial 3 with value: 0.8956358919501614.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:27:36,333] Trial 6 finished with value: 0.9544676329607438 and parameters: {'n_estimators': 100, 'learning_rate': 0.0072653943737840156, 'max_depth': 5, 'subsample': 0.9849420121056763, 'colsample_bytree': 0.6220535944150415}. Best is trial 3 with value: 0.8956358919501614.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:27
. Best is trial 33 with value: 0.8926794547508327.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:30:02,156] Trial 34 finished with value: 0.8928400039488439 and parameters: {'n_estimators': 900, 'learning_rate': 0.02116868334762985, 'max_depth': 5, 'subsample': 0.8536553165268761, 'colsample_bytree': 0.6422974238361682}. Best is trial 33 with value: 0.8926794547508327.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:30:06,601] Trial 35 finished with value: 0.895672146028726 and parameters: {'n_estimators': 900, 'learning_rate': 0.02252202119437998, 'max_depth': 4, 'subsample': 0.7658118749259889, 'colsample_bytree': 0.557454847999375}. Best is trial 33 with value: 0.8926794547508327.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:30:11,566] Trial 36 finished with value: 0.8937847357762427 and parameters: {'n_estimators': 900, 'learning_rate': 0.01764700329341855, 'max_depth': 5, 'subsample': 0.8116549182456175, 'colsample_bytree': 0.6256913427357838}. Best is trial 33 with value: 0.8926794547508327.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:30:17,500] Trial 37 finished with value: 0.8940050605439492 and parameters: {'n_estimators': 900, 'learning_rate': 0.017784180856896478, 'max_depth': 5, 'subsample': 0.8048207474759804, 'colsample_bytree': 0.635579817664303}. Best is trial 33 with value: 0.8926794547508327.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:30:22,841] Trial 38 finished with value: 0.8940173978178988 and parameters: {'n_estimators': 900, 'learning_rate': 0.02320347929089678, 'max_depth': 5, 'subsample': 0.8568399997999634, 'colsample_bytree': 0.6014301947986566}. Best is trial 33 with value: 0.8926794547508327.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:30:26,248] Trial 39 finished with value: 0.9032876954180303 and parameters: {'n_estimators': 700, 'learning_rate': 0.02016619267925931, 'max_depth': 3, 'subsample': 0.8235282755463161, 'colsample_bytree': 0.657625139042031}. Best is trial 33 with value: 0.8926794547508327.
# Time taken: 203.67 seconds

# %%
xgb_best5, xgb_y_pred5, xgb_mse5, xgb_c5, xgb_time5 = xgb(X, y, data, n_trials=50)
# Out:
# [I 2025-03-09 16:30:32,660] A new study created in memory with name: no-name-0f578dcb-aa21-4d80-b91c-46865b444547
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:30:36,638] Trial 0 finished with value: 0.8982198262981225 and parameters: {'n_estimators': 300, 'learning_rate': 0.029613198829594692, 'max_depth': 9, 'subsample': 0.7447178536390442, 'colsample_bytree': 0.8577134086368005}. Best is trial 0 with value: 0.8982198262981225.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:30:40,886] Trial 1 finished with value: 0.9086488120160804 and parameters: {'n_estimators': 700, 'learning_rate': 0.006360986383904084, 'max_depth': 5, 'subsample': 0.9214821281397318, 'colsample_bytree': 0.9566012933351081}. Best is trial 0 with value: 0.8982198262981225.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:30:47,973] Trial 2 finished with value: 0.8980309936904066 and parameters: {'n_estimators': 500, 'learning_rate': 0.01784732425682357, 'max_depth': 10, 'subsample': 0.7109212463775951, 'colsample_bytree': 0.8377277583995631}. Best is trial 2 with value: 0.8980309936904066.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:30:49,314] Trial 3 finished with value: 0.950418655678147 and parameters: {'n_estimators': 100, 'learning_rate': 0.005673722254593196, 'max_depth': 8, 'subsample': 0.6347120447202187, 'colsample_bytree': 0.8888327112381975}. Best is trial 2 with value: 0.8980309936904066.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:30:56,983] Trial 4 finished with value: 0.8979616392100118 and parameters: {'n_estimators': 900, 'learning_rate': 0.021980488000115695, 'max_depth': 8, 'subsample': 0.9905865824318805, 'colsample_bytree': 0.6014802205617126}. Best is trial 4 with value: 0.8979616392100118.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:30:59,730] Trial 5 finished with value: 0.9148486143005636 and parameters: {'n_estimators': 500, 'learning_rate': 0.00756327658524907, 'max_depth': 4, 'subsample': 0.6407835208459911, 'colsample_bytree': 0.9861684428601662}. Best is trial 4 with value: 0.8979616392100118.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:31
. Best is trial 27 with value: 0.8933571622021691.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:32:56,961] Trial 32 finished with value: 0.8949073256201493 and parameters: {'n_estimators': 900, 'learning_rate': 0.03482846698018865, 'max_depth': 4, 'subsample': 0.9495832737541651, 'colsample_bytree': 0.5330269767381278}. Best is trial 27 with value: 0.8933571622021691.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:33:05,354] Trial 33 finished with value: 0.9031532887430864 and parameters: {'n_estimators': 700, 'learning_rate': 0.027040540102291215, 'max_depth': 10, 'subsample': 0.9243686464135873, 'colsample_bytree': 0.5859262593182306}. Best is trial 27 with value: 0.8933571622021691.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:33:12,107] Trial 34 finished with value: 0.8962821085705036 and parameters: {'n_estimators': 900, 'learning_rate': 0.015477050677513217, 'max_depth': 5, 'subsample': 0.9052908078058169, 'colsample_bytree': 0.5320998630927}. Best is trial 27 with value: 0.8933571622021691.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:33:17,074] Trial 35 finished with value: 0.8960728052029796 and parameters: {'n_estimators': 700, 'learning_rate': 0.04431035016198782, 'max_depth': 3, 'subsample': 0.9645288457313823, 'colsample_bytree': 0.613507799729393}. Best is trial 27 with value: 0.8933571622021691.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:33:21,473] Trial 36 finished with value: 0.8940694888003198 and parameters: {'n_estimators': 900, 'learning_rate': 0.03465348717342435, 'max_depth': 4, 'subsample': 0.8769191850958625, 'colsample_bytree': 0.5686625497570216}. Best is trial 27 with value: 0.8933571622021691.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:33:26,599] Trial 37 finished with value: 0.8920959760678027 and parameters: {'n_estimators': 900, 'learning_rate': 0.0348938387701944, 'max_depth': 5, 'subsample': 0.8229389468168163, 'colsample_bytree': 0.5679478170890373}. Best is trial 37 with value: 0.8920959760678027.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:33:30,358] Trial 38 finished with value: 0.8944448600514858 and parameters: {'n_estimators': 500, 'learning_rate': 0.02494798303295033, 'max_depth': 5, 'subsample': 0.8273232834500821, 'colsample_bytree': 0.5793767543429363}. Best is trial 37 with value: 0.8920959760678027.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:33:35,944] Trial 39 finished with value: 0.8953514044056834 and parameters: {'n_estimators': 700, 'learning_rate': 0.021985924054057093, 'max_depth': 7, 'subsample': 0.7317247688147028, 'colsample_bytree': 0.6686292545738266}. Best is trial 37 with value: 0.8920959760678027.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:33:46,861] Trial 40 finished with value: 0.9024773786393777 and parameters: {'n_estimators': 900, 'learning_rate': 0.029246566151184854, 'max_depth': 9, 'subsample': 0.9739879896565686, 'colsample_bytree': 0.6042278410783745}. Best is trial 37 with value: 0.8920959760678027.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:33:51,329] Trial 41 finished with value: 0.8939994320012875 and parameters: {'n_estimators': 900, 'learning_rate': 0.035207103803378104, 'max_depth': 4, 'subsample': 0.8765274988786238, 'colsample_bytree': 0.5525711688919918}. Best is trial 37 with value: 0.8920959760678027.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:33:55,703] Trial 42 finished with value: 0.8931325554036247 and parameters: {'n_estimators': 900, 'learning_rate': 0.03518016785250912, 'max_depth': 4, 'subsample': 0.8206378048125142, 'colsample_bytree': 0.5568093176391735}. Best is trial 37 with value: 0.8920959760678027.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:34:01,485] Trial 43 finished with value: 0.8933221223407716 and parameters: {'n_estimators': 900, 'learning_rate': 0.04396594321870511, 'max_depth': 5, 'subsample': 0.808592968099553, 'colsample_bytree': 0.5544397995559995}. Best is trial 37 with value: 0.8920959760678027.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:34:07,186] Trial 44 finished with value: 0.8988234742228315 and parameters: {'n_estimators': 900, 'learning_rate': 0.04407058518427194, 'max_depth': 6, 'subsample': 0.8099876870106746, 'colsample_bytree': 0.6251255601102021}. Best is trial 37 with value: 0.8920959760678027.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:34:11,331] Trial 45 finished with value: 0.8946278354320502 and parameters: {'n_estimators': 700, 'learning_rate': 0.0433357236880172, 'max_depth': 5, 'subsample': 0.763857629224578, 'colsample_bytree': 0.7072171937672899}. Best is trial 37 with value: 0.8920959760678027.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:34:16,106] Trial 46 finished with value: 0.9018366263223827 and parameters: {'n_estimators': 900, 'learning_rate': 0.01669994130427402, 'max_depth': 3, 'subsample': 0.6087449590422729, 'colsample_bytree': 0.5933497468231934}. Best is trial 37 with value: 0.8920959760678027.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:34:20,390] Trial 47 finished with value: 0.8925631505930371 and parameters: {'n_estimators': 700, 'learning_rate': 0.027800830434729605, 'max_depth': 5, 'subsample': 0.8169563565178222, 'colsample_bytree': 0.5220834350500303}. Best is trial 37 with value: 0.8920959760678027.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:34:24,416] Trial 48 finished with value: 0.9070141542972245 and parameters: {'n_estimators': 700, 'learning_rate': 0.0069021364290859635, 'max_depth': 5, 'subsample': 0.8108578294325526, 'colsample_bytree': 0.563870935566482}. Best is trial 37 with value: 0.8920959760678027.
# C:\Users\ashle\anaconda3\lib\site-packages\optuna\distributions.py:699: UserWarning: The distribution is specified by [100, 1000] and step=200, but the range is not divisible by `step`. It will be replaced by [100, 900].
#   warnings.warn(
# [I 2025-03-09 16:34:29,623] Trial 49 finished with value: 0.8966883514474434 and parameters: {'n_estimators': 700, 'learning_rate': 0.022787845763616758, 'max_depth': 7, 'subsample': 0.6822264538030475, 'colsample_bytree': 0.6414157782767663}. Best is trial 37 with value: 0.8920959760678027.
# Time taken: 242.91 seconds

# %%
# Combine data from XGBoost 
trials = [10, 20, 30, 40, 50]
xgb_c_index_vals = [xgb_c, xgb_c2, xgb_c3, xgb_c4, xgb_c5]
xgb_mse_vals = [xgb_mse, xgb_mse2, xgb_mse3, xgb_mse4, xgb_mse5]
time_vals = [xgb_time, xgb_time2, xgb_time3, xgb_time4, xgb_time5]  

fig, ax1 = plt.subplots()

# Plot MSE on the left y-axis
ax1.set_xlabel("Number of Trials")
ax1.set_ylabel("MSE", color="tab:blue")
ax1.plot(trials, xgb_mse_vals, marker="o", color="tab:blue", label="MSE")
ax1.tick_params(axis="y", labelcolor="tab:blue")

# Create a second y-axis for C-Index
ax2 = ax1.twinx()
ax2.set_ylabel("C-Index", color="tab:red")
ax2.plot(trials, xgb_c_index_vals, marker="s", color="tab:red", label="Time Taken")
ax2.tick_params(axis="y", labelcolor="tab:red")

# Create a third axis for time
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))  # Shift the third axis outward
ax3.set_ylabel("Time Taken (s)", color="tab:green")
ax3.plot(trials, time_vals, marker="^", color="tab:green", label="Time Taken")
ax3.tick_params(axis="y", labelcolor="tab:green")

# Title and layout adjustments
plt.title("XGBoost: MSE, Stratified C-Index, and Time vs. Number of Trials")
fig.tight_layout()
plt.show()

# %% [markdown]
# # Final Comparisons

# %%
# Define data
data = {
    "Best Models": [
        "Ridge regression with 5-fold CV",
        "Lasso with 10-fold CV",
        "XGBoost with 30 trials"
    ],
    "MSE": [mse_ridge_5, mse_lasso_10, xgb_mse3],
    "Stratified C-Index": [c_ridge_5, c_lasso_10, xgb_c3],
    "Time (sec)": [time_ridge_5, time_lasso_10, xgb_time3]
}

# Create DataFrame
df = pd.DataFrame(data)

print(df)
# Out:
#                        Best Models       MSE  Stratified C-Index  Time (sec)
# 0  Ridge regression with 5-fold CV  0.878976            0.637722   33.742024
# 1            Lasso with 10-fold CV  0.878835            0.637391    3.726150
# 2           XGBoost with 50 trials  0.796276            0.651728  137.265980
